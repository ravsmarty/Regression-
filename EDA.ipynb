# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df=pd.read_csv('google_cleaned.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3.6       100  Free    0.0       Everyone
# 10837     NaN        3   9.5      1000  Free    0.0       Everyone
# 10838     4.5      114   NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver         Android Ver  \
# ...

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.sample()
# Out:
#                              App            Category  Rating  Reviews   Size  \
# 6507  BN Pro ArialXL Legacy Text  LIBRARIES_AND_DEMO     4.1      142  0.442
#
#       Installs  Type  Price Content Rating            Genres Last Updated  \
# 6507     10000  Free    0.0       Everyone  Libraries & Demo   2017-02-05
#
#      Current Ver Android Ver  day  month  year
# 6507       2.3.2  1.6 and up    5      2  2017

# %%
df.sample(5)
# Out:
#                                     App          Category  Rating  Reviews  \
# 6821         BU School of Public Health  TRAVEL_AND_LOCAL     NaN        0
# 4394  N Files - File Manager & Explorer      PRODUCTIVITY     4.3      369
# 778           GRE® Flashcards by Kaplan         EDUCATION     4.0      316
# 9683     Masha and The Bear Puzzle Game            FAMILY     4.3    13330
# 6895                              BW-Go              GAME     4.8      265
#
#       Size  Installs  Type  Price Content Rating              Genres  \
# 6821  29.0        10  Free   0.00       Everyone      Travel & Local
# 4394  11.0     10000  Free   0.00       Everyone        Productivity
# 778   29.0     50000  Free   0.00       Everyone           Education
# 9683  73.0   1000000  Free   0.00       Everyone  Puzzle;Brain Games
# 6895   1.3      1000  Paid   3.49       Everyone               Board
#
#      Last Updated Current Ver Android Ver  day  month  year
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# day                  0
# month                0
# year                 0
# dtype: int64

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# day                  0
# month                0
# year                 0
# dtype: int64

# %%
df.describe()
# Out:
#             Rating       Reviews         Size      Installs         Price  \
# count  9366.000000  1.084000e+04  9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05    21.506534  1.546434e+07      1.027368
# std       0.515219  2.927761e+06    22.596021  8.502936e+07     15.949703
# min       1.000000  0.000000e+00     0.010000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01     4.900000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03    13.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04    30.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09    400.000000
#
#                 day         month          year
# count  10840.000000  10840.000000  10840.000000
# mean      15.609041      6.422325   2017.399723
# std        9.561621      2.578388      1.100914
# min        1.000000      1.000000   2010.000000
# 25%        6.000000      5.000000   2017.000000
# ...

# %%
df.describe().T
# Out:
#             count          mean           std      min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.00     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.00    38.0    2094.0
# Size       9145.0  2.150653e+01  2.259602e+01     0.01     4.9      13.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.00  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.00     0.0       0.0
# day       10840.0  1.560904e+01  9.561621e+00     1.00     6.0      16.0
# month     10840.0  6.422325e+00  2.578388e+00     1.00     5.0       7.0
# year      10840.0  2.017400e+03  1.100914e+00  2010.00  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size           30.0  1.000000e+02
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# ...

# %%
df.describe(include='all')
# Out:
#            App Category       Rating       Reviews         Size      Installs  \
# count    10840    10840  9366.000000  1.084000e+04  9145.000000  1.084000e+04
# unique    9659       33          NaN           NaN          NaN           NaN
# top     ROBLOX   FAMILY          NaN           NaN          NaN           NaN
# freq         9     1972          NaN           NaN          NaN           NaN
# mean       NaN      NaN     4.191757  4.441529e+05    21.506534  1.546434e+07
# std        NaN      NaN     0.515219  2.927761e+06    22.596021  8.502936e+07
# min        NaN      NaN     1.000000  0.000000e+00     0.010000  0.000000e+00
# 25%        NaN      NaN     4.000000  3.800000e+01     4.900000  1.000000e+03
# 50%        NaN      NaN     4.300000  2.094000e+03    13.000000  1.000000e+05
# 75%        NaN      NaN     4.500000  5.477550e+04    30.000000  5.000000e+06
# max        NaN      NaN     5.000000  7.815831e+07   100.000000  1.000000e+09
#
# ...

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
l1=[1,2,3,3,3,5,5,5,7,7,8]

# %%
df1=pd.DataFrame(l1)

# %%
df1
# Out:
#     0
# 0   1
# 1   2
# 2   3
# 3   3
# 4   3
# 5   5
# 6   5
# 7   5
# 8   7
# 9   7
# 10  8

# %%
df1.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8     False
# 9      True
# 10    False
# dtype: bool

# %%
df1[df1.duplicated()]
# Out:
#    0
# 3  3
# 4  3
# 6  5
# 7  5
# 9  7

# %%
df1.drop_duplicates()
# Out:
#     0
# 0   1
# 1   2
# 2   3
# 5   5
# 8   7
# 10  8

# %%
df1.head()
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  3
# 4  3

# %%
df1.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8     False
# 9      True
# 10    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (10840, 16)

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
num_feature=[feature for feature in df.columns if df[feature].dtype!='O']

# %%
[feature for feature in df.columns if df[feature].dtype!='O']
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
cat_feature=[feature for feature in df.columns if df[feature].dtype=='O']

# %%
num_feature
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
cat_feature
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Out:
#   File "<ipython-input-31-352b3727fd99>", line 1
#     ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                                                                                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
len(df["App"].value_counts())
# Out:
# 9659

# %%
cat_df=df[cat_feature]

# %%
num_df=df[num_feature]

# %%
#distribution of numrrical col
#check the distribution of the numeric variable
sns.kde----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------num_df['Rating']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-a4586f172776> in <module>
#       1 #distribution of numrrical col
#       2 #check the distribution of the numeric variable
# ----> 3 sns.kde----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------num_df['Rating']
#
# AttributeError: module 'seaborn' has no attribute 'kde'

# %%
-----------------------------------------------sns.kdeplot(num_df['Rating'])---------------
# Out:
#   File "<ipython-input-36-7591fc2b025b>", line 1
#     -----------------------------------------------sns.kdeplot(num_df['Rating'])---------------
#                                                                                                ^
# SyntaxError: invalid syntax

# %%
for feature in num_feature:
    sns.kdeplot(num_df[feature])
    plt.xlabel(feature)
    plt.ylabel("count")
    plt.title("this is kde plot")
    plt.show()

# %%
# observation : our data is normally distributed or not or outlier.

# %%
# eda with category variable
cat_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
cat_df['Type'].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-7c9528e136b1> in <module>
# ----> 1 cat_df['Type'].value_count()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5459                 return self[name]
# -> 5460             return object.__getattribute__(self, name)
#    5461
#    5462     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
sns.countplot(cat_df['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
cat_df['Content Rating'].value_counts()
# Out:
# Everyone           8382
# Teen               1146
# Mature 17+          447
# Everyone 10+        377
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
sns.countplot(cat_df['Content Rating'])
plt.xlabel("c")
plt.ylabel("y")
plt.title("count plot with respect to content rating")
# Out:
# Text(0.5, 1.0, 'count plot with respect to content rating')

# %%
sns.countplot(cat_df['Genres'])
plt.xlabel("c")
plt.ylabel("y")
plt.title("count plot with respect to content rating")
# Out:
# Text(0.5, 1.0, 'count plot with respect to content rating')

# %%
sns.countplot(cat_df['Android Ver'])
plt.xlabel("c")
plt.ylabel("y")
plt.title("count plot with respect to content rating")
# Out:
# Text(0.5, 1.0, 'count plot with respect to content rating')

# %%
for feature in cat_feature:
    sns.countplot(cat_df[feature])
    plt.xlabel(feature)
    plt.ylabel('value')
    plt.title('count plot')
    plt.show()
    -----------------------------------------------------------------------------------------------------------------------------

# %% [raw]
#  which one will be  most popuplar category

# %%
cat_df['Category'].value_counts().plot.pie(figsize=(20,20))
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
cat_df['Category'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
category=pd.DataFrame(cat_df['Category'].value_counts())

# %%
category.rename(columns={'Category':'Count'},inplace=True)

# %%
category.head(10)
# Out:
#                  Count
# FAMILY            1943
# GAME              1121
# TOOLS              843
# BUSINESS           427
# MEDICAL            408
# PRODUCTIVITY       407
# PERSONALIZATION    388
# LIFESTYLE          373
# COMMUNICATION      366
# FINANCE            360

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=category.index[:10],y="Count",data=category[:10])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
x=category.index[:12]

# %%
x
# Out:
# Index(['FAMILY', 'GAME', 'TOOLS', 'BUSINESS', 'MEDICAL', 'PRODUCTIVITY',
#        'PERSONALIZATION', 'LIFESTYLE', 'COMMUNICATION', 'FINANCE', 'SPORTS',
#        'PHOTOGRAPHY'],
#       dtype='object')

# %%
plt.figure(figsize=(20,20))
sns.countplot(category['Count'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='count'>

# %%
cat_df.head()
# Out:
#                                                  App        Category  Type  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN  Free
# 1                                Coloring book moana  ART_AND_DESIGN  Free
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN  Free
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN  Free
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN  Free
#
#   Content Rating                     Genres Last Updated         Current Ver  \
# 0       Everyone               Art & Design   2018-01-07               1.0.0
# 1       Everyone  Art & Design;Pretend Play   2018-01-15               2.0.0
# 2       Everyone               Art & Design   2018-08-01               1.2.4
# 3           Teen               Art & Design   2018-06-08  Varies with device
# 4       Everyone    Art & Design;Creativity   2018-06-20                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# ...

# %%
num_df.head()
# Out:
#    Rating  Reviews  Size  Installs  Price  day  month  year
# 0     4.1      159  19.0     10000    0.0    7      1  2018
# 1     3.9      967  14.0    500000    0.0   15      1  2018
# 2     4.7    87510   8.7   5000000    0.0    1      8  2018
# 3     4.5   215644  25.0  50000000    0.0    8      6  2018
# 4     4.3      967   2.8    100000    0.0   20      6  2018

# %%
cat_max=num_df['Installs'].max()

# %%
cat_max
# Out:
# 1000000000

# %%
df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   31544024415
# COMMUNICATION          24152276251
# SOCIAL                 12513867902
# PRODUCTIVITY           12463091369
# TOOLS                  11452771915
# FAMILY                 10041692505
# PHOTOGRAPHY             9721247655
# TRAVEL_AND_LOCAL        6361887146
# VIDEO_PLAYERS           6222002720
# NEWS_AND_MAGAZINES      5393217760
# SHOPPING                2573348785
# ENTERTAINMENT           2455660000
# PERSONALIZATION         2074494782
# BOOKS_AND_REFERENCE     1916469576
# SPORTS                  1528574498
# HEALTH_AND_FITNESS      1361022512
# BUSINESS                 863664865
# FINANCE                  770348734
# MAPS_AND_NAVIGATION      724281890
# LIFESTYLE                534823539
# EDUCATION                533952000
# WEATHER                  426100520
# FOOD_AND_DRINK           257898751
# DATING                   206536107
# HOUSE_AND_HOME           125212461
# ART_AND_DESIGN           124338100
# ...

# %%
df.groupby(['Category'])['Installs'].sum().nlargest(10)
# Out:
# Category
# GAME                  31544024415
# COMMUNICATION         24152276251
# SOCIAL                12513867902
# PRODUCTIVITY          12463091369
# TOOLS                 11452771915
# FAMILY                10041692505
# PHOTOGRAPHY            9721247655
# TRAVEL_AND_LOCAL       6361887146
# VIDEO_PLAYERS          6222002720
# NEWS_AND_MAGAZINES     5393217760
# Name: Installs, dtype: int64

# %%
df.groupby(['Category'])['Installs'].sum().nlargest(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='Installs'>

# %%
df.groupby(['Category'])['Installs'].sum().nlargest(10).plot.bar(figsize=(20,20))
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# #  Assignments of the datys
# # 1how many apps are there on oogle play store which gets 5 ratings?
# # 2.dpes size of application impact on its popularity?
# # 3.what are the top 5 most install app in each popular category.
# # 4.which category app users are reviewing the most
# # 5.which category app users are reviewing the most?

# %%
df.value_counts("Type").plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
# linear regressing
num_df.head()
# Out:
#    Rating  Reviews  Size  Installs  Price  day  month  year
# 0     4.1      159  19.0     10000    0.0    7      1  2018
# 1     3.9      967  14.0    500000    0.0   15      1  2018
# 2     4.7    87510   8.7   5000000    0.0    1      8  2018
# 3     4.5   215644  25.0  50000000    0.0    8      6  2018
# 4     4.3      967   2.8    100000    0.0   20      6  2018

# %% [markdown]
# # Q. you need to create a model(linear regresion) where all the festure except rating will be implemented feature and will be a dependent feature using swklearn.linear regression.
